# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ## Proje 3
#
# [7,5,1,8,3,6 0,9,4,2] dizisinin Binary-Search-Tree aşamalarını yazınız.
#
# Örnek: root x'dir. root'un sağından y bulunur. Solunda z bulunur vb.

# %% [markdown]
# Bir Binary Search Tree (BST) oluştururken, dizinin elemanlarını sırayla alırız ve her bir elemanı ağaçta uygun konuma yerleştiririz. Ağaç yapısı, her düğümün solundaki tüm değerlerin o düğümden küçük, sağındaki tüm değerlerin o düğümden büyük olmasını sağlar.
#
# * 1. Aşama: root = 7
#
# * 2. Aşama: 5, 7'den küçük olduğu için soluna yerleştirilir
#
# * 3. Aşama: 1, 5'ten küçük olduğu için 5'in soluna yerleştirilir.
#
# * 4. Aşama: 8, 7'den büyük olduğu için 7'nin sağına yerleştirilir.
#
# * 5. Aşama: 3, 1'den büyük olduğu için 1'in sağına yerleştirilir.
#
# * 6. Aşama: 6, 5'ten büyük olduğu için 5'in sağına yerleştirilir.
#
# * 7. Aşama: 0, 1'den küçük olduğu için 1'in soluna yerleştirilir.
#
# * 8. Aşama: 9, 8'den büyük olduğu için 8'in sağına yerleştirilir.
#
# * 9. Aşama: 4, 3'ten büyük olduğu için 3'ün sağına yerleştirilir
#
# * 10. Aşama: 2, 3'ten küçük olduğu için 3'ün soluna yerleştirilir
#
# ![image.png](attachment:770be103-1f99-4981-895b-9848840f3eab.png)
